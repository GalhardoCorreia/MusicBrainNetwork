# %% [markdown]
# # Music and the Brain

# %% [markdown]
# ## 0. Setup

# %%
import os 


import nilearn

import numpy as np
import pandas as pd

import nibabel as nib

from nilearn import plotting
from nilearn import image
from nilearn.plotting import plot_anat, plot_img, plot_stat_map

# %%
# Set the path to the data directory
src_dir = '../data/'

# Set the participant and session IDs
part_id = 'sub-01'
ses_id = 'ses-01'

# Path to the T1w image
anat_path = os.path.join(src_dir, part_id, ses_id, 'anat', f'{part_id}_{ses_id}_space-MNI152NLin2009cAsym_res-2_desc-preproc_T1w.nii.gz')

# Path to functional image
funcdir_path = os.path.join(src_dir, part_id, ses_id, 'func')

# %%
results_dir = '../results/'

# %% [markdown]
# ### 0.1 Anatomical data

# %%
plot_anat(anat_path, title='T1w image', display_mode='ortho', dim=-1, draw_cross=False, annotate=False, cut_coords=(0, 0, 0))

# %% [markdown]
# ### 0.2 Functional data

# %%
# list directory contents with extension 'nii.gz'
func_runs = os.listdir(funcdir_path)
func_runs = [f for f in func_runs if f.endswith('bold.nii.gz')]

# Sort the list
func_runs.sort()

print(func_runs)
# Out:
# ['sub-01_ses-01_task-02a_run-1_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz', 'sub-01_ses-01_task-02a_run-2_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz', 'sub-01_ses-01_task-02a_run-3_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz', 'sub-01_ses-01_task-02a_run-4_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz']

# %%
from nilearn.image import mean_img 

# Load the first functional image
func_image = image.load_img(os.path.join(funcdir_path,func_runs[0]))

mfunc_img = mean_img(func_image)

plot_img(mfunc_img)

# %% [markdown]
# #### 0.2.1 Events

# %%
fdir_events = [file for file in os.listdir(funcdir_path) if file.endswith('.tsv')]

f_events = [os.path.join(funcdir_path, f) for f in fdir_events]

# %%
f_events.sort()

# %%
f_events
# Out:
# ['../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-1_events.tsv',
#  '../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-2_events.tsv',
#  '../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-3_events.tsv',
#  '../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-4_events.tsv']

# %%
for fn in f_events:
    # Load the events.tsv file
    events = pd.read_table(fn)

    # Get the file name
    events_info = os.path.basename(fn)

    # Print the image information
    print(events_info) 
    
    # pd.read_table function is used to read a general delimited file into a pandas DataFrame
    print(events)
# Out:
# sub-01_ses-01_task-02a_run-1_events.tsv
#      onset  duration        trial_type
# 0     0.00     12.25             Noise
# 1    12.25     24.00        Tenderness
# 2    36.24      5.93             Noise
# 3    42.18     24.08        Tenderness
# 4    66.25     17.99             Noise
# 5    84.25     24.06            Wonder
# 6   108.30      5.98             Noise
# 7   114.28     23.97            Wonder
# 8   138.25     17.93             Noise
# 9   156.19     24.07         Nostalgia
# 10  180.26      6.37             Noise
# 11  186.62     23.63         Nostalgia
# 12  210.25     18.15             Noise
# 13  228.40     23.86      Peacefulness
# 14  252.26      5.94             Noise
# 15  258.20     24.07      Peacefulness
# 16  282.26     17.96             Noise
# 17  300.22     24.03     Transcendence
# 18  324.26      5.94             Noise
# 19  330.20     24.07     Transcendence
# 20  354.27     18.00             Noise
# 21  372.27     24.07           Sadness
# 22  396.33      5.99             Noise
# 23  402.32     24.01           Sadness
# 24  426.34     17.92             Noise
# 25  444.26     24.07             Power
# 26  468.33      5.95             Noise
# 27  474.27     24.03             Power
# 28  498.30     17.97             Noise
# 29  516.27     24.10           Tension
# 30  540.37      5.91             Noise
# 31  546.28     24.02           Tension
# 32  570.30     17.93             Noise
# 33  588.23     24.33  JoyfulActivation
# 34  612.56      5.66             Noise
# 35  618.21     24.19  JoyfulActivation
# 36  642.41     17.59             Noise
# sub-01_ses-01_task-02a_run-2_events.tsv
#      onset  duration        trial_type
# 0     0.00     12.26             Noise
# 1    12.26     23.98     Transcendence
# 2    36.24      6.01             Noise
# 3    42.25     24.00     Transcendence
# 4    66.25     17.99             Noise
# 5    84.24     24.05           Sadness
# 6   108.29      5.98             Noise
# 7   114.26     24.00           Sadness
# 8   138.26     18.03             Noise
# 9   156.30     23.98           Tension
# 10  180.28      6.01             Noise
# 11  186.29     23.96           Tension
# 12  210.26     18.03             Noise
# 13  228.28     23.98  JoyfulActivation
# 14  252.26      6.02             Noise
# 15  258.28     24.00  JoyfulActivation
# 16  282.28     18.03             Noise
# 17  300.31     23.94             Power
# 18  324.25      6.01             Noise
# 19  330.27     24.00             Power
# 20  354.27     17.98             Noise
# 21  372.25     24.08        Tenderness
# 22  396.33      5.94             Noise
# 23  402.27     24.30        Tenderness
# 24  426.56     17.86             Noise
# 25  444.42     24.00            Wonder
# 26  468.42      6.02             Noise
# 27  474.44     24.06            Wonder
# 28  498.50     17.96             Noise
# 29  516.45     23.98         Nostalgia
# 30  540.43      6.00             Noise
# 31  546.43     24.01         Nostalgia
# 32  570.44     17.98             Noise
# 33  588.42     24.03      Peacefulness
# 34  612.45      6.11             Noise
# 35  618.55     23.87      Peacefulness
# 36  642.43     17.57             Noise
# sub-01_ses-01_task-02a_run-3_events.tsv
#      onset  duration        trial_type
# 0     0.00     12.24             Noise
# 1    12.24     24.14           Sadness
# 2    36.38      5.88             Noise
# 3    42.27     24.05           Sadness
# 4    66.31     17.95             Noise
# 5    84.26     24.06  JoyfulActivation
# 6   108.32      6.09             Noise
# 7   114.40     23.84  JoyfulActivation
# 8   138.25     18.00             Noise
# 9   156.25     24.01        Tenderness
# 10  180.26      5.99             Noise
# 11  186.25     24.00        Tenderness
# 12  210.25     18.06             Noise
# 13  228.31     23.94           Tension
# 14  252.25      6.08             Noise
# 15  258.32     23.93           Tension
# 16  282.26     18.09             Noise
# 17  300.34     23.91             Power
# 18  324.25      6.00             Noise
# 19  330.25     24.00             Power
# 20  354.26     18.01             Noise
# 21  372.27     23.99         Nostalgia
# 22  396.26      6.00             Noise
# 23  402.25     24.01         Nostalgia
# 24  426.27     17.99             Noise
# 25  444.25     24.01            Wonder
# 26  468.26      6.00             Noise
# 27  474.27     24.01            Wonder
# 28  498.28     17.99             Noise
# 29  516.27     24.00      Peacefulness
# 30  540.27      6.06             Noise
# 31  546.33     23.94      Peacefulness
# 32  570.27     18.02             Noise
# 33  588.29     23.98     Transcendence
# 34  612.27      6.02             Noise
# 35  618.29     24.13     Transcendence
# 36  642.42     17.58             Noise
# sub-01_ses-01_task-02a_run-4_events.tsv
#      onset  duration        trial_type
# 0     0.00     12.25             Noise
# 1    12.25     24.16           Sadness
# 2    36.41      5.87             Noise
# 3    42.28     23.96           Sadness
# 4    66.25     18.04             Noise
# 5    84.28     24.15      Peacefulness
# 6   108.43      5.82             Noise
# 7   114.25     24.07      Peacefulness
# 8   138.33     17.93             Noise
# 9   156.25     24.03     Transcendence
# 10  180.28      5.98             Noise
# 11  186.26     24.07     Transcendence
# 12  210.33     17.93             Noise
# 13  228.26     23.99        Tenderness
# 14  252.25      6.01             Noise
# 15  258.26     23.98        Tenderness
# 16  282.25     18.01             Noise
# 17  300.26     24.00            Wonder
# 18  324.26      6.01             Noise
# 19  330.27     24.02            Wonder
# 20  354.28     18.04             Noise
# 21  372.33     23.98  JoyfulActivation
# 22  396.31      6.00             Noise
# 23  402.30     24.08  JoyfulActivation
# 24  426.38     17.88             Noise
# 25  444.26     24.08             Power
# 26  468.34      5.92             Noise
# 27  474.27     24.02             Power
# 28  498.28     17.99             Noise
# 29  516.27     24.07         Nostalgia
# 30  540.34      5.93             Noise
# 31  546.26     24.00         Nostalgia
# 32  570.26     18.02             Noise
# 33  588.28     24.07           Tension
# 34  612.35      5.96             Noise
# 35  618.31     23.97           Tension
# 36  642.29     17.71             Noise

# %% [markdown]
# # 1 Creation of Input dataset and Target vectors

# %%
from nilearn.image import index_img 

run_id = 0

image_set = {}
target_set = {}
group_set = {}

idx = 0

offset_st = 4 # offset for the onset time
offset_end = 2 # offset for the end block time

# for each events file 
for fn in f_events:

    print(os.path.join(funcdir_path,func_runs[run_id]), fn)
    
    # Load the events.tsv file
    events = pd.read_table(fn)

    # create one image per event 
    for i, row in events.iterrows():

        # Print the row information
        print(row) 

        # Extract the onset time
        onset = np.round(row['onset'])

        # Extract the duration
        duration = np.round(row['duration'])

        # Extract the trial_type
        trial_type = row['trial_type']

        # Print the row information
        print(onset, duration, trial_type) 

        # if duration greater than 10
        if duration > 10 and onset + duration + offset_end < 660:

            # array with onset to onset+duration
            i_idxs = np.arange(onset + offset_st, onset + duration + offset_end, 1, dtype=int)

            # create mean_img based on i_idxs
            mean_img_i = mean_img(index_img( 
                os.path.join(funcdir_path,func_runs[run_id]), 
                i_idxs))

            image_set[idx] = mean_img_i
            target_set[idx] = trial_type
            group_set[idx] = run_id

            idx += 1


    run_id += 1
# Out:
# ../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-1_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz ../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-1_events.tsv
# onset           0.0
# duration      12.25
# trial_type    Noise
# Name: 0, dtype: object
# 0.0 12.0 Noise
# onset              12.25
# duration            24.0
# trial_type    Tenderness
# Name: 1, dtype: object
# 12.0 24.0 Tenderness
# onset         36.24
# duration       5.93
# trial_type    Noise
# Name: 2, dtype: object
# 36.0 6.0 Noise
# onset              42.18
# duration           24.08
# trial_type    Tenderness
# Name: 3, dtype: object
# 42.0 24.0 Tenderness
# onset         66.25
# duration      17.99
# trial_type    Noise
# Name: 4, dtype: object
# 66.0 18.0 Noise
# onset          84.25
# duration       24.06
# trial_type    Wonder
# Name: 5, dtype: object
# 84.0 24.0 Wonder
# onset         108.3
# duration       5.98
# trial_type    Noise
# Name: 6, dtype: object
# 108.0 6.0 Noise
# onset         114.28
# duration       23.97
# trial_type    Wonder
# Name: 7, dtype: object
# 114.0 24.0 Wonder
# onset         138.25
# duration       17.93
# trial_type     Noise
# Name: 8, dtype: object
# 138.0 18.0 Noise
# onset            156.19
# duration          24.07
# trial_type    Nostalgia
# Name: 9, dtype: object
# 156.0 24.0 Nostalgia
# onset         180.26
# duration        6.37
# trial_type     Noise
# Name: 10, dtype: object
# 180.0 6.0 Noise
# onset            186.62
# duration          23.63
# trial_type    Nostalgia
# Name: 11, dtype: object
# 187.0 24.0 Nostalgia
# onset         210.25
# duration       18.15
# trial_type     Noise
# Name: 12, dtype: object
# 210.0 18.0 Noise
# onset                228.4
# duration             23.86
# trial_type    Peacefulness
# Name: 13, dtype: object
# 228.0 24.0 Peacefulness
# onset         252.26
# duration        5.94
# trial_type     Noise
# Name: 14, dtype: object
# 252.0 6.0 Noise
# onset                258.2
# duration             24.07
# trial_type    Peacefulness
# Name: 15, dtype: object
# 258.0 24.0 Peacefulness
# onset         282.26
# duration       17.96
# trial_type     Noise
# Name: 16, dtype: object
# 282.0 18.0 Noise
# onset                300.22
# duration              24.03
# trial_type    Transcendence
# Name: 17, dtype: object
# 300.0 24.0 Transcendence
# onset         324.26
# duration        5.94
# trial_type     Noise
# Name: 18, dtype: object
# 324.0 6.0 Noise
# onset                 330.2
# duration              24.07
# trial_type    Transcendence
# Name: 19, dtype: object
# 330.0 24.0 Transcendence
# onset         354.27
# duration        18.0
# trial_type     Noise
# Name: 20, dtype: object
# 354.0 18.0 Noise
# onset          372.27
# duration        24.07
# trial_type    Sadness
# Name: 21, dtype: object
# 372.0 24.0 Sadness
# onset         396.33
# duration        5.99
# trial_type     Noise
# Name: 22, dtype: object
# 396.0 6.0 Noise
# onset          402.32
# duration        24.01
# trial_type    Sadness
# Name: 23, dtype: object
# 402.0 24.0 Sadness
# onset         426.34
# duration       17.92
# trial_type     Noise
# Name: 24, dtype: object
# 426.0 18.0 Noise
# onset         444.26
# duration       24.07
# trial_type     Power
# Name: 25, dtype: object
# 444.0 24.0 Power
# onset         468.33
# duration        5.95
# trial_type     Noise
# Name: 26, dtype: object
# 468.0 6.0 Noise
# onset         474.27
# duration       24.03
# trial_type     Power
# Name: 27, dtype: object
# 474.0 24.0 Power
# onset         498.3
# duration      17.97
# trial_type    Noise
# Name: 28, dtype: object
# 498.0 18.0 Noise
# onset          516.27
# duration         24.1
# trial_type    Tension
# Name: 29, dtype: object
# 516.0 24.0 Tension
# onset         540.37
# duration        5.91
# trial_type     Noise
# Name: 30, dtype: object
# 540.0 6.0 Noise
# onset          546.28
# duration        24.02
# trial_type    Tension
# Name: 31, dtype: object
# 546.0 24.0 Tension
# onset         570.3
# duration      17.93
# trial_type    Noise
# Name: 32, dtype: object
# 570.0 18.0 Noise
# onset                   588.23
# duration                 24.33
# trial_type    JoyfulActivation
# Name: 33, dtype: object
# 588.0 24.0 JoyfulActivation
# onset         612.56
# duration        5.66
# trial_type     Noise
# Name: 34, dtype: object
# 613.0 6.0 Noise
# onset                   618.21
# duration                 24.19
# trial_type    JoyfulActivation
# Name: 35, dtype: object
# 618.0 24.0 JoyfulActivation
# onset         642.41
# duration       17.59
# trial_type     Noise
# Name: 36, dtype: object
# 642.0 18.0 Noise
# ../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-2_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz ../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-2_events.tsv
# onset           0.0
# duration      12.26
# trial_type    Noise
# Name: 0, dtype: object
# 0.0 12.0 Noise
# onset                 12.26
# duration              23.98
# trial_type    Transcendence
# Name: 1, dtype: object
# 12.0 24.0 Transcendence
# onset         36.24
# duration       6.01
# trial_type    Noise
# Name: 2, dtype: object
# 36.0 6.0 Noise
# onset                 42.25
# duration               24.0
# trial_type    Transcendence
# Name: 3, dtype: object
# 42.0 24.0 Transcendence
# onset         66.25
# duration      17.99
# trial_type    Noise
# Name: 4, dtype: object
# 66.0 18.0 Noise
# onset           84.24
# duration        24.05
# trial_type    Sadness
# Name: 5, dtype: object
# 84.0 24.0 Sadness
# onset         108.29
# duration        5.98
# trial_type     Noise
# Name: 6, dtype: object
# 108.0 6.0 Noise
# onset          114.26
# duration         24.0
# trial_type    Sadness
# Name: 7, dtype: object
# 114.0 24.0 Sadness
# onset         138.26
# duration       18.03
# trial_type     Noise
# Name: 8, dtype: object
# 138.0 18.0 Noise
# onset           156.3
# duration        23.98
# trial_type    Tension
# Name: 9, dtype: object
# 156.0 24.0 Tension
# onset         180.28
# duration        6.01
# trial_type     Noise
# Name: 10, dtype: object
# 180.0 6.0 Noise
# onset          186.29
# duration        23.96
# trial_type    Tension
# Name: 11, dtype: object
# 186.0 24.0 Tension
# onset         210.26
# duration       18.03
# trial_type     Noise
# Name: 12, dtype: object
# 210.0 18.0 Noise
# onset                   228.28
# duration                 23.98
# trial_type    JoyfulActivation
# Name: 13, dtype: object
# 228.0 24.0 JoyfulActivation
# onset         252.26
# duration        6.02
# trial_type     Noise
# Name: 14, dtype: object
# 252.0 6.0 Noise
# onset                   258.28
# duration                  24.0
# trial_type    JoyfulActivation
# Name: 15, dtype: object
# 258.0 24.0 JoyfulActivation
# onset         282.28
# duration       18.03
# trial_type     Noise
# Name: 16, dtype: object
# 282.0 18.0 Noise
# onset         300.31
# duration       23.94
# trial_type     Power
# Name: 17, dtype: object
# 300.0 24.0 Power
# onset         324.25
# duration        6.01
# trial_type     Noise
# Name: 18, dtype: object
# 324.0 6.0 Noise
# onset         330.27
# duration        24.0
# trial_type     Power
# Name: 19, dtype: object
# 330.0 24.0 Power
# onset         354.27
# duration       17.98
# trial_type     Noise
# Name: 20, dtype: object
# 354.0 18.0 Noise
# onset             372.25
# duration           24.08
# trial_type    Tenderness
# Name: 21, dtype: object
# 372.0 24.0 Tenderness
# onset         396.33
# duration        5.94
# trial_type     Noise
# Name: 22, dtype: object
# 396.0 6.0 Noise
# onset             402.27
# duration            24.3
# trial_type    Tenderness
# Name: 23, dtype: object
# 402.0 24.0 Tenderness
# onset         426.56
# duration       17.86
# trial_type     Noise
# Name: 24, dtype: object
# 427.0 18.0 Noise
# onset         444.42
# duration        24.0
# trial_type    Wonder
# Name: 25, dtype: object
# 444.0 24.0 Wonder
# onset         468.42
# duration        6.02
# trial_type     Noise
# Name: 26, dtype: object
# 468.0 6.0 Noise
# onset         474.44
# duration       24.06
# trial_type    Wonder
# Name: 27, dtype: object
# 474.0 24.0 Wonder
# onset         498.5
# duration      17.96
# trial_type    Noise
# Name: 28, dtype: object
# 498.0 18.0 Noise
# onset            516.45
# duration          23.98
# trial_type    Nostalgia
# Name: 29, dtype: object
# 516.0 24.0 Nostalgia
# onset         540.43
# duration         6.0
# trial_type     Noise
# Name: 30, dtype: object
# 540.0 6.0 Noise
# onset            546.43
# duration          24.01
# trial_type    Nostalgia
# Name: 31, dtype: object
# 546.0 24.0 Nostalgia
# onset         570.44
# duration       17.98
# trial_type     Noise
# Name: 32, dtype: object
# 570.0 18.0 Noise
# onset               588.42
# duration             24.03
# trial_type    Peacefulness
# Name: 33, dtype: object
# 588.0 24.0 Peacefulness
# onset         612.45
# duration        6.11
# trial_type     Noise
# Name: 34, dtype: object
# 612.0 6.0 Noise
# onset               618.55
# duration             23.87
# trial_type    Peacefulness
# Name: 35, dtype: object
# 619.0 24.0 Peacefulness
# onset         642.43
# duration       17.57
# trial_type     Noise
# Name: 36, dtype: object
# 642.0 18.0 Noise
# ../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-3_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz ../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-3_events.tsv
# onset           0.0
# duration      12.24
# trial_type    Noise
# Name: 0, dtype: object
# 0.0 12.0 Noise
# onset           12.24
# duration        24.14
# trial_type    Sadness
# Name: 1, dtype: object
# 12.0 24.0 Sadness
# onset         36.38
# duration       5.88
# trial_type    Noise
# Name: 2, dtype: object
# 36.0 6.0 Noise
# onset           42.27
# duration        24.05
# trial_type    Sadness
# Name: 3, dtype: object
# 42.0 24.0 Sadness
# onset         66.31
# duration      17.95
# trial_type    Noise
# Name: 4, dtype: object
# 66.0 18.0 Noise
# onset                    84.26
# duration                 24.06
# trial_type    JoyfulActivation
# Name: 5, dtype: object
# 84.0 24.0 JoyfulActivation
# onset         108.32
# duration        6.09
# trial_type     Noise
# Name: 6, dtype: object
# 108.0 6.0 Noise
# onset                    114.4
# duration                 23.84
# trial_type    JoyfulActivation
# Name: 7, dtype: object
# 114.0 24.0 JoyfulActivation
# onset         138.25
# duration        18.0
# trial_type     Noise
# Name: 8, dtype: object
# 138.0 18.0 Noise
# onset             156.25
# duration           24.01
# trial_type    Tenderness
# Name: 9, dtype: object
# 156.0 24.0 Tenderness
# onset         180.26
# duration        5.99
# trial_type     Noise
# Name: 10, dtype: object
# 180.0 6.0 Noise
# onset             186.25
# duration            24.0
# trial_type    Tenderness
# Name: 11, dtype: object
# 186.0 24.0 Tenderness
# onset         210.25
# duration       18.06
# trial_type     Noise
# Name: 12, dtype: object
# 210.0 18.0 Noise
# onset          228.31
# duration        23.94
# trial_type    Tension
# Name: 13, dtype: object
# 228.0 24.0 Tension
# onset         252.25
# duration        6.08
# trial_type     Noise
# Name: 14, dtype: object
# 252.0 6.0 Noise
# onset          258.32
# duration        23.93
# trial_type    Tension
# Name: 15, dtype: object
# 258.0 24.0 Tension
# onset         282.26
# duration       18.09
# trial_type     Noise
# Name: 16, dtype: object
# 282.0 18.0 Noise
# onset         300.34
# duration       23.91
# trial_type     Power
# Name: 17, dtype: object
# 300.0 24.0 Power
# onset         324.25
# duration         6.0
# trial_type     Noise
# Name: 18, dtype: object
# 324.0 6.0 Noise
# onset         330.25
# duration        24.0
# trial_type     Power
# Name: 19, dtype: object
# 330.0 24.0 Power
# onset         354.26
# duration       18.01
# trial_type     Noise
# Name: 20, dtype: object
# 354.0 18.0 Noise
# onset            372.27
# duration          23.99
# trial_type    Nostalgia
# Name: 21, dtype: object
# 372.0 24.0 Nostalgia
# onset         396.26
# duration         6.0
# trial_type     Noise
# Name: 22, dtype: object
# 396.0 6.0 Noise
# onset            402.25
# duration          24.01
# trial_type    Nostalgia
# Name: 23, dtype: object
# 402.0 24.0 Nostalgia
# onset         426.27
# duration       17.99
# trial_type     Noise
# Name: 24, dtype: object
# 426.0 18.0 Noise
# onset         444.25
# duration       24.01
# trial_type    Wonder
# Name: 25, dtype: object
# 444.0 24.0 Wonder
# onset         468.26
# duration         6.0
# trial_type     Noise
# Name: 26, dtype: object
# 468.0 6.0 Noise
# onset         474.27
# duration       24.01
# trial_type    Wonder
# Name: 27, dtype: object
# 474.0 24.0 Wonder
# onset         498.28
# duration       17.99
# trial_type     Noise
# Name: 28, dtype: object
# 498.0 18.0 Noise
# onset               516.27
# duration              24.0
# trial_type    Peacefulness
# Name: 29, dtype: object
# 516.0 24.0 Peacefulness
# onset         540.27
# duration        6.06
# trial_type     Noise
# Name: 30, dtype: object
# 540.0 6.0 Noise
# onset               546.33
# duration             23.94
# trial_type    Peacefulness
# Name: 31, dtype: object
# 546.0 24.0 Peacefulness
# onset         570.27
# duration       18.02
# trial_type     Noise
# Name: 32, dtype: object
# 570.0 18.0 Noise
# onset                588.29
# duration              23.98
# trial_type    Transcendence
# Name: 33, dtype: object
# 588.0 24.0 Transcendence
# onset         612.27
# duration        6.02
# trial_type     Noise
# Name: 34, dtype: object
# 612.0 6.0 Noise
# onset                618.29
# duration              24.13
# trial_type    Transcendence
# Name: 35, dtype: object
# 618.0 24.0 Transcendence
# onset         642.42
# duration       17.58
# trial_type     Noise
# Name: 36, dtype: object
# 642.0 18.0 Noise
# ../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-4_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz ../data/sub-01/ses-01/func/sub-01_ses-01_task-02a_run-4_events.tsv
# onset           0.0
# duration      12.25
# trial_type    Noise
# Name: 0, dtype: object
# 0.0 12.0 Noise
# onset           12.25
# duration        24.16
# trial_type    Sadness
# Name: 1, dtype: object
# 12.0 24.0 Sadness
# onset         36.41
# duration       5.87
# trial_type    Noise
# Name: 2, dtype: object
# 36.0 6.0 Noise
# onset           42.28
# duration        23.96
# trial_type    Sadness
# Name: 3, dtype: object
# 42.0 24.0 Sadness
# onset         66.25
# duration      18.04
# trial_type    Noise
# Name: 4, dtype: object
# 66.0 18.0 Noise
# onset                84.28
# duration             24.15
# trial_type    Peacefulness
# Name: 5, dtype: object
# 84.0 24.0 Peacefulness
# onset         108.43
# duration        5.82
# trial_type     Noise
# Name: 6, dtype: object
# 108.0 6.0 Noise
# onset               114.25
# duration             24.07
# trial_type    Peacefulness
# Name: 7, dtype: object
# 114.0 24.0 Peacefulness
# onset         138.33
# duration       17.93
# trial_type     Noise
# Name: 8, dtype: object
# 138.0 18.0 Noise
# onset                156.25
# duration              24.03
# trial_type    Transcendence
# Name: 9, dtype: object
# 156.0 24.0 Transcendence
# onset         180.28
# duration        5.98
# trial_type     Noise
# Name: 10, dtype: object
# 180.0 6.0 Noise
# onset                186.26
# duration              24.07
# trial_type    Transcendence
# Name: 11, dtype: object
# 186.0 24.0 Transcendence
# onset         210.33
# duration       17.93
# trial_type     Noise
# Name: 12, dtype: object
# 210.0 18.0 Noise
# onset             228.26
# duration           23.99
# trial_type    Tenderness
# Name: 13, dtype: object
# 228.0 24.0 Tenderness
# onset         252.25
# duration        6.01
# trial_type     Noise
# Name: 14, dtype: object
# 252.0 6.0 Noise
# onset             258.26
# duration           23.98
# trial_type    Tenderness
# Name: 15, dtype: object
# 258.0 24.0 Tenderness
# onset         282.25
# duration       18.01
# trial_type     Noise
# Name: 16, dtype: object
# 282.0 18.0 Noise
# onset         300.26
# duration        24.0
# trial_type    Wonder
# Name: 17, dtype: object
# 300.0 24.0 Wonder
# onset         324.26
# duration        6.01
# trial_type     Noise
# Name: 18, dtype: object
# 324.0 6.0 Noise
# onset         330.27
# duration       24.02
# trial_type    Wonder
# Name: 19, dtype: object
# 330.0 24.0 Wonder
# onset         354.28
# duration       18.04
# trial_type     Noise
# Name: 20, dtype: object
# 354.0 18.0 Noise
# onset                   372.33
# duration                 23.98
# trial_type    JoyfulActivation
# Name: 21, dtype: object
# 372.0 24.0 JoyfulActivation
# onset         396.31
# duration         6.0
# trial_type     Noise
# Name: 22, dtype: object
# 396.0 6.0 Noise
# onset                    402.3
# duration                 24.08
# trial_type    JoyfulActivation
# Name: 23, dtype: object
# 402.0 24.0 JoyfulActivation
# onset         426.38
# duration       17.88
# trial_type     Noise
# Name: 24, dtype: object
# 426.0 18.0 Noise
# onset         444.26
# duration       24.08
# trial_type     Power
# Name: 25, dtype: object
# 444.0 24.0 Power
# onset         468.34
# duration        5.92
# trial_type     Noise
# Name: 26, dtype: object
# 468.0 6.0 Noise
# onset         474.27
# duration       24.02
# trial_type     Power
# Name: 27, dtype: object
# 474.0 24.0 Power
# onset         498.28
# duration       17.99
# trial_type     Noise
# Name: 28, dtype: object
# 498.0 18.0 Noise
# onset            516.27
# duration          24.07
# trial_type    Nostalgia
# Name: 29, dtype: object
# 516.0 24.0 Nostalgia
# onset         540.34
# duration        5.93
# trial_type     Noise
# Name: 30, dtype: object
# 540.0 6.0 Noise
# onset            546.26
# duration           24.0
# trial_type    Nostalgia
# Name: 31, dtype: object
# 546.0 24.0 Nostalgia
# onset         570.26
# duration       18.02
# trial_type     Noise
# Name: 32, dtype: object
# 570.0 18.0 Noise
# onset          588.28
# duration        24.07
# trial_type    Tension
# Name: 33, dtype: object
# 588.0 24.0 Tension
# onset         612.35
# duration        5.96
# trial_type     Noise
# Name: 34, dtype: object
# 612.0 6.0 Noise
# onset          618.31
# duration        23.97
# trial_type    Tension
# Name: 35, dtype: object
# 618.0 24.0 Tension
# onset         642.29
# duration       17.71
# trial_type     Noise
# Name: 36, dtype: object
# 642.0 18.0 Noise

# %%
# size/shape of the image_set
print('Image set size: '+ str(len(image_set)))

# size/shape of the target_set
print('Target vector: '+ str(len(target_set)))

# print unique values in target_set
print('Labels: ')  
print(np.unique(list(target_set.values())))


# size/shape of the group_set
print('Run group vector: '+ str(len(group_set)))
# Out:
# Image set size: 108
# Target vector: 108
# Labels:
# ['JoyfulActivation' 'Noise' 'Nostalgia' 'Peacefulness' 'Power' 'Sadness'
#  'Tenderness' 'Tension' 'Transcendence' 'Wonder']
# Run group vector: 108

# %%
# Remove the noise condition 

# create a new image_set, target_set and group_set
image_set_clean = {}
target_set_clean = {}
group_set_clean = {}

idx = 0

# for each image in image_set

for i in image_set:

    # if the target is not 'noise'
    if target_set[i] != 'Noise':
        image_set_clean[idx] = image_set[i]
        target_set_clean[idx] = target_set[i]
        group_set_clean[idx] = group_set[i]
        idx += 1

# size/shape of the image_set_clean
print('Image set size: '+ str(len(image_set_clean)))

# size/shape of the target_set_clean
print('Target vector: '+ str(len(target_set_clean)))
# Out:
# Image set size: 72
# Target vector: 72

# %%
# change the target_set to target_set_clean
target_set = target_set_clean

# change the image_set to image_set_clean
image_set = image_set_clean

# change the group_set to group_set_clean
group_set = group_set_clean

# %%
# Save the image_set, target_set, and group_set in the derivatives directory inside the data directory
deriv_dir = os.path.join(src_dir, 'derivatives')

if not os.path.exists(deriv_dir):
    os.makedirs(deriv_dir)


# package folder structure
results_dir = os.path.join(deriv_dir, 'nilearn')

if not os.path.exists(results_dir):
    os.makedirs(results_dir)


data_fldr= os.path.join(results_dir, part_id, ses_id)

# if the directory for the participant and session does not exist, create it
if not os.path.exists(data_fldr):
    os.makedirs(data_fldr)


# concat images in list
X = nilearn.image.concat_imgs(list(image_set.values()))
print(X.shape)

# Save the image_set using nibabel.save and BIDS naming convention
nib.save(X, os.path.join(data_fldr, f'{part_id}_{ses_id}_task-02a-MVPA-12sBOLD.nii.gz'))

# Save the target_set to csv using pandas
pd.Series(target_set, name = 'target').to_csv(os.path.join(data_fldr, f'{part_id}_{ses_id}_task-02a-MVPA-12sBOLD_targets.csv'))

# Save the group_set to csv using pandas
pd.Series(group_set, name = 'group').to_csv(os.path.join(data_fldr, f'{part_id}_{ses_id}_task-02a-MVPA-12sBOLD_groups.csv'))
# Out:
# (97, 115, 97, 72)

# %% [markdown]
# # 2. Create masks

# %%
c_func_runs = [os.path.join(funcdir_path, f) for f in func_runs]

# %%
# Masking the data

from nilearn.masking import compute_epi_mask, compute_multi_epi_mask

mask_img = compute_multi_epi_mask(c_func_runs)

# %%
# plot mask image
plot_img(mask_img)

# %%
# save mask image
nib.save(mask_img, os.path.join(data_fldr, f'{part_id}_{ses_id}_task-02a-MVPA_multi-epi-mask.nii.gz'))
